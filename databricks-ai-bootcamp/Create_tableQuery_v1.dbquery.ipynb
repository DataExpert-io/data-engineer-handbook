-- %%
Drop table if exists LearnDB.Student;

create table LearnDB.Student(StudentId int primary key,name varchar(10), age int,class varchar(5));

insert into learndb.student values(1,'luffy', 17,'S'),(2,'zoro', 18,'S'),(3,'sanji', 19,'S'),(4,'nami', 20,'S'),(5,'usopp', 21,'S'),(6,'chopper', 22,'S'),(7,'robin', 23,'S'),(8,'franky', 24,'S'),(9,'brook', 25,'S'),(10,'jimbei', 26,'S');

insert into learndb.student values(11,'naruto',17,'B'),(12,'sasuke',18,'B'),(13,'sakura',19,'B'),(14,'hinata',20,'B'),(15,'shikamaru',21,'B'),(16,'neji',22,'B'),(17,'kiba',23,'B'),(18,'shino',24,'B'),(19,'akamaru',25,'B'),(20,'boruto',26,'B');

insert into learndb.student values(21,'goku',17,'A'),(22,'vegeta',18,'A'),(23,'gohan',19,'A'),(24,'krillin',20,'A'),(25,'piccolo',21,'A'),(26,'cell',22,'A'),(27,'bulma',23,'A'),(28,'trunks',24,'A'),(29,'goten',25,'A'),(30,'krillin',26,'A');

select * from LearnDB.Student;

Drop table if exists LearnDB.Marks;

create table LearnDB.Marks(StudentId int,subject varchar(10),marks int);

-- One Piece characters (Class S): StudentId 1-10
insert into learndb.marks values
(1,'maths',75),(2,'maths',65),(3,'maths',82),(4,'maths',95),(5,'maths',70),(6,'maths',92),(7,'maths',98),(8,'maths',94),(9,'maths',78),(10,'maths',88),
-- Naruto characters (Class B): StudentId 11-20
(11,'maths',72),(12,'maths',96),(13,'maths',89),(14,'maths',84),(15,'maths',98),(16,'maths',93),(17,'maths',76),(18,'maths',87),(19,'maths',45),(20,'maths',74),
-- Dragon Ball characters (Class A): StudentId 21-30
(21,'maths',58),(22,'maths',81),(23,'maths',99),(24,'maths',73),(25,'maths',86),(26,'maths',90),(27,'maths',100),(28,'maths',85),(29,'maths',69),(30,'maths',73);

-- One Piece characters (Class S): StudentId 1-10
insert into learndb.marks values
(1,'english',70),(2,'english',62),(3,'english',85),(4,'english',92),(5,'english',68),(6,'english',88),(7,'english',99),(8,'english',80),(9,'english',95),(10,'english',90),
-- Naruto characters (Class B): StudentId 11-20
(11,'english',70),(12,'english',92),(13,'english',91),(14,'english',86),(15,'english',88),(16,'english',90),(17,'english',74),(18,'english',85),(19,'english',40),(20,'english',76),
-- Dragon Ball characters (Class A): StudentId 21-30
(21,'english',55),(22,'english',78),(23,'english',97),(24,'english',71),(25,'english',89),(26,'english',87),(27,'english',100),(28,'english',83),(29,'english',66),(30,'english',71);


-- One Piece characters (Class S): StudentId 1-10
insert into learndb.marks values
(1,'science',78),(2,'science',68),(3,'science',88),(4,'science',90),(5,'science',75),(6,'science',98),(7,'science',96),(8,'science',97),(9,'science',72),(10,'science',91),
-- Naruto characters (Class B): StudentId 11-20
(11,'science',75),(12,'science',94),(13,'science',95),(14,'science',82),(15,'science',95),(16,'science',91),(17,'science',79),(18,'science',92),(19,'science',42),(20,'science',77),
-- Dragon Ball characters (Class A): StudentId 21-30
(21,'science',60),(22,'science',82),(23,'science',100),(24,'science',75),(25,'science',88),(26,'science',93),(27,'science',100),(28,'science',87),(29,'science',68),(30,'science',75);

SELECT * FROM LearnDB.Marks
