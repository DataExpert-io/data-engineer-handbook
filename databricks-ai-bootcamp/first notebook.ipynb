# %%
dataframe = spark.sql("SELECT * from dataexpert_student.company_aggregate")

# create_table = spark.sql("CREATE TABLE IF NOT EXISTS dataexpert_student.company_aggregate (company VARCHAR(32), max_age INTEGER, min_age INTEGER)")

# aggregated_dateframe = spark.sql("insert into dataexpert_student.company_aggregate SELECT company, MAX(age) as max_age, min(age) as min_age from dataexpert_student.student_table GROUP BY company")



dataframe.collect()
